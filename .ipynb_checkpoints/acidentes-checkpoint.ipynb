# %% [markdown]
# #### PANDAS é uma <strong>biblioteca</strong> de manipulação e análise de dados em Python. Ela permite que você trabalhe com dados de forma eficiente e intuitiva, similar ao que você faria no Excel, mas com muito mais flexibilidade e poder.

# %%
import pandas as pd
df = pd.read_csv('C:\Desktop\cat_acidentes.csv', sep = ';')

# %% [markdown]
# ##### df - DataFrame

# %%
df
# Out:
#              data_extracao  predial1  queda_arr                 data  feridos  \
# 0      2024-06-01 01:33:30       0.0        0.0  2020-10-17 00:00:00        1
# 1      2024-06-01 01:33:30    6699.0        0.0  2019-01-01 00:00:00        1
# 2      2024-06-01 01:33:30     411.0        0.0  2019-01-01 00:00:00        1
# 3      2024-06-01 01:33:30    1500.0        0.0  2019-01-01 00:00:00        4
# 4      2024-06-01 01:33:30    8799.0        0.0  2019-01-01 00:00:00        5
# ...                    ...       ...        ...                  ...      ...
# 69373  2024-06-01 01:33:30     925.0        0.0  2024-05-21 00:00:00        1
# 69374  2024-06-01 01:33:30     133.0        0.0  2024-05-21 00:00:00        0
# 69375  2024-06-01 01:33:30     317.0        0.0  2024-05-15 00:00:00        1
# 69376  2024-06-01 01:33:30     220.0        0.0  2024-05-21 00:00:00        2
# 69377  2024-06-01 01:33:30     901.0        0.0  2024-05-15 00:00:00        1
#
# ...

# %%
# !pip install folium

# %%
import folium
from folium.plugins import HeatMap
mapa = folium.Map(location=[-30.1, -51.15], zoom_start=11)
#coordenadas = list(zip(df.latitude, df.longitude))
#mapa_calor = HeatMap(coordenadas)
#mapa.add_child(mapa_calor)
#exibe o mapa
mapa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import folium
#       2 from folium.plugins import HeatMap
#       3 mapa = folium.Map(location=[-30.1, -51.15], zoom_start=11)
#
# ModuleNotFoundError: No module named 'folium'
